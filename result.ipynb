# %%
import pandas as pd

# %%
res = pd.read_csv("./outputs/experiments_results.csv")

# %%
res
# Out:
#    selector experiment             model           r2        rmse  \
# 0    logsum   baseline  LinearRegression -8539.175821  169.361925
# 1    logsum   baseline             Lasso     0.298373    1.535095
# 2    logsum   baseline      RandomForest     0.254498    1.582365
# 3    logsum   baseline          LightGBM     0.287555    1.546885
# 4    logsum     optuna             Lasso     0.299019    1.534389
# 5    logsum     optuna      RandomForest     0.289808    1.544438
# 6    logsum     optuna          LightGBM     0.299448    1.533919
# 7      shap   baseline  LinearRegression     0.276599    1.558734
# 8      shap   baseline             Lasso     0.273274    1.562312
# 9      shap   baseline      RandomForest     0.230078    1.608072
# 10     shap   baseline          LightGBM     0.274745    1.560729
# 11     shap     optuna             Lasso     0.276682    1.558644
# 12     shap     optuna      RandomForest     0.275717    1.559684
# ...

# %%
new_rows = pd.DataFrame([
    {"selector": "no_selection", "experiment": "baseline", "model" : "LinerRegression", "r2": 0.037778, "rmse": 1.797711, "adj_r2": -0.388162, "rse": 2.159555, "best_params": None},
    {"selector": "no_selection", "experiment": "baseline", "model" : "Lasso", "r2": 0.298314, "rmse": 1.535160, "adj_r2": -0.012296, "rse": 1.844158, "best_params": None},
    {"selector": "no_selection", "experiment": "baseline", "model" : "RandomForest", "r2": 0.261876, "rmse": 1.574516, "adj_r2": -0.064864, "rse": 1.891435, "best_params": None},
    {"selector": "no_selection", "experiment": "baseline", "model" : "LightGBM", "r2": 0.282033, "rmse": 1.552868, "adj_r2": -0.035785, "rse": 1.865430, "best_params": None}
])

# %%
df = pd.concat([res,new_rows], ignore_index=True)

# %%
df
# Out:
#         selector experiment             model           r2        rmse  \
# 0         logsum   baseline  LinearRegression -8539.175821  169.361925
# 1         logsum   baseline             Lasso     0.298373    1.535095
# 2         logsum   baseline      RandomForest     0.254498    1.582365
# 3         logsum   baseline          LightGBM     0.287555    1.546885
# 4         logsum     optuna             Lasso     0.299019    1.534389
# 5         logsum     optuna      RandomForest     0.289808    1.544438
# 6         logsum     optuna          LightGBM     0.299448    1.533919
# 7           shap   baseline  LinearRegression     0.276599    1.558734
# 8           shap   baseline             Lasso     0.273274    1.562312
# 9           shap   baseline      RandomForest     0.230078    1.608072
# 10          shap   baseline          LightGBM     0.274745    1.560729
# 11          shap     optuna             Lasso     0.276682    1.558644
# ...
